# %% [markdown]
# <a href="https://colab.research.google.com/github/danysc/DA-Projects/blob/main/Courses_Reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Courses_Reviews

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# from collections import Counter

# %% [markdown]
# Read the data from my Github:

# %%
# Read the csv from my GitHub
data_set = pd.read_csv('https://raw.githubusercontent.com/danysc/DA-Projects/main/Courses_Reviews.csv')
data_set.head()
# Out:
#    course_id course_subject  ... content_duration_minutes       published_date
# 0     182554   Anthropology  ...                      940  2015-06-01 00:00:00
# 1     110977   Anthropology  ...                     1890  2017-10-02 00:00:00
# 2     129475   Anthropology  ...                      520  2017-01-03 00:00:00
# 3     133955   Anthropology  ...                     1650  2018-02-03 00:00:00
# 4     172121   Anthropology  ...                     1975  2018-12-25 00:00:00
#
# [5 rows x 11 columns]

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   course_id                 592 non-null    int64
#  1   course_subject            592 non-null    object
#  2   course_title              592 non-null    object
#  3   price_usd                 592 non-null    int64
#  4   course_level              592 non-null    object
#  5   num_students              592 non-null    int64
#  6   positive_reviews          592 non-null    int64
#  7   negative_reviews          592 non-null    int64
#  8   num_lessons               592 non-null    int64
#  9   content_duration_minutes  592 non-null    int64
#  10  published_date            592 non-null    object
# dtypes: int64(7), object(4)
# memory usage: 51.0+ KB

# %% [markdown]
# Show the size of the DF:

# %%
print(data_set.shape)
# Out:
# (592, 11)

# %%
nRow, nCol = data_set.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 592 rows and 11 columns

# %%
# List of the columns:
columnNames = list(data_set)
columnNames
# Out:
# ['course_id',
#  'course_subject',
#  'course_title',
#  'price_usd',
#  'course_level',
#  'num_students',
#  'positive_reviews',
#  'negative_reviews',
#  'num_lessons',
#  'content_duration_minutes',
#  'published_date']

# %%
# Genaral DataFrame view:
data_set
# Out:
#      course_id   course_subject  ... content_duration_minutes       published_date
# 0       182554     Anthropology  ...                      940  2015-06-01 00:00:00
# 1       110977     Anthropology  ...                     1890  2017-10-02 00:00:00
# 2       129475     Anthropology  ...                      520  2017-01-03 00:00:00
# 3       133955     Anthropology  ...                     1650  2018-02-03 00:00:00
# 4       172121     Anthropology  ...                     1975  2018-12-25 00:00:00
# ..         ...              ...  ...                      ...                  ...
# 587     123205  Medical physics  ...                      400  2016-05-13 00:00:00
# 588     143585  Medical physics  ...                      925  2015-03-06 00:00:00
# 589     172219  Medical physics  ...                     1625  2015-05-24 00:00:00
# 590     178195  Medical physics  ...                     1620  2016-04-09 00:00:00
# ...

# %%
data_set['price_usd'].max()
# Out:
# 69

# %%
data_set['price_usd'].min()
# Out:
# 20

# %%
# Set the precision of the results:
pd.set_option("display.precision", 1)

# %%
# Convert the Date columns to date format:
data_set['published_date'] = pd.to_datetime(data_set['published_date'])
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   course_id                 592 non-null    int64
#  1   course_subject            592 non-null    object
#  2   course_title              592 non-null    object
#  3   price_usd                 592 non-null    int64
#  4   course_level              592 non-null    object
#  5   num_students              592 non-null    int64
#  6   positive_reviews          592 non-null    int64
#  7   negative_reviews          592 non-null    int64
#  8   num_lessons               592 non-null    int64
#  9   content_duration_minutes  592 non-null    int64
#  10  published_date            592 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int64(7), object(3)
# memory usage: 51.0+ KB

# %% [markdown]
# Add a column of the sum of positive_reviews + negative_reviews:

# %%
data_set[['course_id','num_students']].assign(total_reviews = \
                                              data_set['positive_reviews'] + data_set['negative_reviews'])\
.head()
# Out:
#    course_id  num_students  total_reviews
# 0     182554          2495            183
# 1     110977          2775            542
# 2     129475          5703             71
# 3     133955          9045            464
# 4     172121          1087            317

# %% [markdown]
# Group By: Find the courses with the large negative reviews:

# %%
data_set.groupby(['course_subject'])\
.agg(Sum_Neg_Rev = ('negative_reviews','sum'))\
  .sort_values('Sum_Neg_Rev', ascending = False)\
  .head(7)
# Out:
#                  Sum_Neg_Rev
# course_subject
# Philosophy             17847
# History                17135
# Economics              15477
# Medical physics        14461
# Anthropology           13672
# Performing arts        13631
# Archaeology            11106

# %% [markdown]
# Groupby the course by "course_level", find the sum of the students,
# and sort the results:

# %%
# Group By: Find the courses with the large negative reviews:
data_set.groupby(['course_level']).agg(students_mean = ('num_students', 'sum'))\
  .sort_values('students_mean', ascending = False)\
  .head()
# Out:
#               students_mean
# course_level
# Intermediate        1097513
# Beginner            1060977
# Advanced            1040105

# %% [markdown]
# Groupby the course by "course_level", find the students mean,
# and sort the results:

# %%
data_set.groupby(['course_level']).agg(students_mean = ('num_students', 'mean'))\
  .sort_values('students_mean', ascending = False)\
  .head()
# Out:
#               students_mean
# course_level
# Intermediate         5628.3
# Beginner             5469.0
# Advanced             5123.7

# %% [markdown]
# Groupby the course by "course subject", find the students mean, and sort the results:

# %%
data_set.groupby(['course_subject']).agg(num_students_mean = ('num_students','mean'))\
  .sort_values('num_students_mean', ascending = False)\
  .head(10)
# Out:
#                            num_students_mean
# course_subject
# Performing arts                       6051.3
# Anthropology                          5629.8
# Religion                              5612.2
# History                               5599.4
# Linguistics and languages             5534.9
# Medical physics                       5507.9
# Visual arts                           5446.4
# Economics                             5308.6
# Geography                             5289.5
# European studies                      5287.9
